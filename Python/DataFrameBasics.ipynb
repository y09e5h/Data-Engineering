# %%
import datetime

import pandas as pd

# %%
df = pd.read_csv("movies.csv")

# %%
df.head()
# Out:
#                                          title   industry  release_year  \
# 0                              Pather Panchali  Bollywood          1955
# 1  Doctor Strange in the Multiverse of Madness  Hollywood          2022
# 2                        Thor: The Dark World   Hollywood          2013
# 3                              Thor: Ragnarok   Hollywood          2017
# 4                      Thor: Love and Thunder   Hollywood          2022
#
#    imdb_rating                     studio   budget   revenue       unit  \
# 0          8.3  Government of West Bengal  70000.0  100000.0  Thousands
# 1          7.0             Marvel Studios    200.0     954.8   Millions
# 2          6.8             Marvel Studios    165.0     644.8   Millions
# 3          7.9             Marvel Studios    180.0     854.0   Millions
# 4          6.8             Marvel Studios    250.0     670.0   Millions
#
#   currency language
# 0      INR  Bengali
# 1      USD  English
# 2      USD  English
# ...

# %%
df.shape
# Out:
# (37, 10)

# %%
df["industry"].unique()
# Out:
# array(['Bollywood', 'Hollywood'], dtype=object)

# %%
df["language"].unique()
# Out:
# array(['Bengali', 'English', 'Hindi', 'Kannada', 'Telugu'], dtype=object)

# %%
df["industry"].value_counts()
# Out:
# industry
# Hollywood    20
# Bollywood    17
# Name: count, dtype: int64

# %%
new_df=df[["title","industry","imdb_rating",]]
new_df.head()
# Out:
#                                          title   industry  imdb_rating
# 0                              Pather Panchali  Bollywood          8.3
# 1  Doctor Strange in the Multiverse of Madness  Hollywood          7.0
# 2                        Thor: The Dark World   Hollywood          6.8
# 3                              Thor: Ragnarok   Hollywood          7.9
# 4                      Thor: Love and Thunder   Hollywood          6.8

# %%
df[(df["release_year"] >= 2000) & (df["release_year"] <= 2020)]
# Out:
#                                   title   industry  release_year  imdb_rating  \
# 2                 Thor: The Dark World   Hollywood          2013          6.8
# 3                       Thor: Ragnarok   Hollywood          2017          7.9
# 6                          Interstellar  Hollywood          2014          8.6
# 7              The Pursuit of Happyness  Hollywood          2006          8.0
# 8                             Gladiator  Hollywood          2000          8.5
# 11                               Avatar  Hollywood          2009          7.8
# 13                      The Dark Knight  Hollywood          2008          9.0
# 16                             Parasite  Hollywood          2019          8.5
# 17                    Avengers: Endgame  Hollywood          2019          8.4
# 18               Avengers: Infinity War  Hollywood          2018          8.4
# 19   Captain America: The First Avenger  Hollywood          2011          6.9
# ...

# %%
df[df["studio"]=="Marvel Studios"]
# Out:
#                                           title   industry  release_year  \
# 1   Doctor Strange in the Multiverse of Madness  Hollywood          2022
# 2                         Thor: The Dark World   Hollywood          2013
# 3                               Thor: Ragnarok   Hollywood          2017
# 4                       Thor: Love and Thunder   Hollywood          2022
# 17                            Avengers: Endgame  Hollywood          2019
# 18                       Avengers: Infinity War  Hollywood          2018
# 19           Captain America: The First Avenger  Hollywood          2011
# 20          Captain America: The Winter Soldier  Hollywood          2014
#
#     imdb_rating          studio  budget  revenue      unit currency language
# 1           7.0  Marvel Studios   200.0    954.8  Millions      USD  English
# 2           6.8  Marvel Studios   165.0    644.8  Millions      USD  English
# 3           7.9  Marvel Studios   180.0    854.0  Millions      USD  English
# ...

# %%
df["studio"]=="Marvel Studios"
# Out:
# 0     False
# 1      True
# 2      True
# 3      True
# 4      True
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17     True
# 18     True
# 19     True
# 20     True
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# 32    False
# 33    False
# 34    False
# 35    False
# 36    False
# Name: studio, dtype: bool

# %%
df.describe()
# Out:
#        release_year  imdb_rating        budget        revenue
# count     37.000000    36.000000     37.000000      37.000000
# mean    2007.027027     7.919444   2084.975135    4117.135135
# std       17.657995     1.204947  11477.487145   16372.462682
# min     1946.000000     1.900000      1.000000       3.100000
# 25%     2001.000000     7.800000     15.500000     263.100000
# 50%     2014.000000     8.100000    165.000000     701.800000
# 75%     2018.000000     8.400000    250.000000    2000.000000
# max     2022.000000     9.300000  70000.000000  100000.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37 entries, 0 to 36
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   title         37 non-null     object
#  1   industry      37 non-null     object
#  2   release_year  37 non-null     int64
#  3   imdb_rating   36 non-null     float64
#  4   studio        34 non-null     object
#  5   budget        37 non-null     float64
#  6   revenue       37 non-null     float64
#  7   unit          37 non-null     object
#  8   currency      37 non-null     object
#  9   language      37 non-null     object
# dtypes: float64(3), int64(1), object(6)
# memory usage: 3.0+ KB

# %%
df[df["imdb_rating"]==df["imdb_rating"].max()]
# Out:
#                       title   industry  release_year  imdb_rating  \
# 5  The Shawshank Redemption  Hollywood          1994          9.3
#
#                       studio  budget  revenue      unit currency language
# 5  Castle Rock Entertainment    25.0     73.3  Millions      USD  English

# %%
now = datetime.datetime.now().year
df["age"] = df["release_year"].apply(lambda x: now - x)
df.head()
# Out:
#                                          title   industry  release_year  \
# 0                              Pather Panchali  Bollywood          1955
# 1  Doctor Strange in the Multiverse of Madness  Hollywood          2022
# 2                        Thor: The Dark World   Hollywood          2013
# 3                              Thor: Ragnarok   Hollywood          2017
# 4                      Thor: Love and Thunder   Hollywood          2022
#
#    imdb_rating                     studio   budget   revenue       unit  \
# 0          8.3  Government of West Bengal  70000.0  100000.0  Thousands
# 1          7.0             Marvel Studios    200.0     954.8   Millions
# 2          6.8             Marvel Studios    165.0     644.8   Millions
# 3          7.9             Marvel Studios    180.0     854.0   Millions
# 4          6.8             Marvel Studios    250.0     670.0   Millions
#
#   currency language  age
# 0      INR  Bengali   70
# 1      USD  English    3
# ...

# %%
df["profit"] = df.apply(lambda x: x["revenue"]-x["budget"], axis=1)

# %%
df.head()
# Out:
#                                          title   industry  release_year  \
# 0                              Pather Panchali  Bollywood          1955
# 1  Doctor Strange in the Multiverse of Madness  Hollywood          2022
# 2                        Thor: The Dark World   Hollywood          2013
# 3                              Thor: Ragnarok   Hollywood          2017
# 4                      Thor: Love and Thunder   Hollywood          2022
#
#    imdb_rating                     studio   budget   revenue       unit  \
# 0          8.3  Government of West Bengal  70000.0  100000.0  Thousands
# 1          7.0             Marvel Studios    200.0     954.8   Millions
# 2          6.8             Marvel Studios    165.0     644.8   Millions
# 3          7.9             Marvel Studios    180.0     854.0   Millions
# 4          6.8             Marvel Studios    250.0     670.0   Millions
#
#   currency language  age   profit
# 0      INR  Bengali   70  30000.0
# ...

# %%
df.set_index("title", inplace=True)

# %%
df.head()
# Out:
#                                               industry  release_year  \
# title
# Pather Panchali                              Bollywood          1955
# Doctor Strange in the Multiverse of Madness  Hollywood          2022
# Thor: The Dark World                         Hollywood          2013
# Thor: Ragnarok                               Hollywood          2017
# Thor: Love and Thunder                       Hollywood          2022
#
#                                              imdb_rating  \
# title
# Pather Panchali                                      8.3
# Doctor Strange in the Multiverse of Madness          7.0
# Thor: The Dark World                                 6.8
# Thor: Ragnarok                                       7.9
# Thor: Love and Thunder                               6.8
#
#                                                                 studio  \
# title
# Pather Panchali                              Government of West Bengal
# ...

# %%
df.index
# Out:
# Index(['Pather Panchali', 'Doctor Strange in the Multiverse of Madness',
#        'Thor: The Dark World ', 'Thor: Ragnarok ', 'Thor: Love and Thunder ',
#        'The Shawshank Redemption', 'Interstellar', 'The Pursuit of Happyness',
#        'Gladiator', 'Titanic', 'It's a Wonderful Life', 'Avatar',
#        'The Godfather', 'The Dark Knight', 'Schindler's List', 'Jurassic Park',
#        'Parasite', 'Avengers: Endgame', 'Avengers: Infinity War',
#        'Captain America: The First Avenger',
#        'Captain America: The Winter Soldier', 'Dilwale Dulhania Le Jayenge',
#        '3 Idiots', 'Kabhi Khushi Kabhie Gham', 'Bajirao Mastani ',
#        'Taare Zameen Par', 'Munna Bhai M.B.B.S.', 'PK', 'Sanju',
#        'The Kashmir Files', 'Bajrangi Bhaijaan', 'Race 3', 'Shershaah',
#        'K.G.F: Chapter 2', 'Pushpa: The Rise - Part 1', 'RRR',
#        'Baahubali: The Beginning'],
#       dtype='object', name='title')

# %%
df.loc["The Godfather"]
# Out:
# industry                 Hollywood
# release_year                  1972
# imdb_rating                    9.2
# studio          Paramount Pictures
# budget                         7.2
# revenue                      291.0
# unit                      Millions
# currency                       USD
# language                   English
# age                             53
# profit                       283.8
# Name: The Godfather, dtype: object

# %%
df.iloc[2]
# Out:
# industry             Hollywood
# release_year              2013
# imdb_rating                6.8
# studio          Marvel Studios
# budget                   165.0
# revenue                  644.8
# unit                  Millions
# currency                   USD
# language               English
# age                         12
# profit                   479.8
# Name: Thor: The Dark World , dtype: object

# %%
df.iloc[2,7]
# Out:
# 'USD'

# %%
df.iloc[3:7]
# Out:
#                            industry  release_year  imdb_rating  \
# title
# Thor: Ragnarok            Hollywood          2017          7.9
# Thor: Love and Thunder    Hollywood          2022          6.8
# The Shawshank Redemption  Hollywood          1994          9.3
# Interstellar              Hollywood          2014          8.6
#
#                                              studio  budget  revenue  \
# title
# Thor: Ragnarok                       Marvel Studios   180.0    854.0
# Thor: Love and Thunder               Marvel Studios   250.0    670.0
# The Shawshank Redemption  Castle Rock Entertainment    25.0     73.3
# Interstellar                  Warner Bros. Pictures   165.0    701.8
#
#                               unit currency language  age  profit
# title
# Thor: Ragnarok            Millions      USD  English    8   674.0
# Thor: Love and Thunder    Millions      USD  English    3   420.0
# The Shawshank Redemption  Millions      USD  English   31    48.3
# ...

# %%
df.reset_index()
# Out:
#                                           title   industry  release_year  \
# 0                               Pather Panchali  Bollywood          1955
# 1   Doctor Strange in the Multiverse of Madness  Hollywood          2022
# 2                         Thor: The Dark World   Hollywood          2013
# 3                               Thor: Ragnarok   Hollywood          2017
# 4                       Thor: Love and Thunder   Hollywood          2022
# 5                      The Shawshank Redemption  Hollywood          1994
# 6                                  Interstellar  Hollywood          2014
# 7                      The Pursuit of Happyness  Hollywood          2006
# 8                                     Gladiator  Hollywood          2000
# 9                                       Titanic  Hollywood          1997
# 10                        It's a Wonderful Life  Hollywood          1946
# 11                                       Avatar  Hollywood          2009
# ...

# %%
df.set_index("industry",inplace=True)
df.head()
# Out:
#            release_year  imdb_rating                     studio   budget  \
# industry
# Bollywood          1955          8.3  Government of West Bengal  70000.0
# Hollywood          2022          7.0             Marvel Studios    200.0
# Hollywood          2013          6.8             Marvel Studios    165.0
# Hollywood          2017          7.9             Marvel Studios    180.0
# Hollywood          2022          6.8             Marvel Studios    250.0
#
#             revenue       unit currency language  age   profit
# industry
# Bollywood  100000.0  Thousands      INR  Bengali   70  30000.0
# Hollywood     954.8   Millions      USD  English    3    754.8
# Hollywood     644.8   Millions      USD  English   12    479.8
# Hollywood     854.0   Millions      USD  English    8    674.0
# Hollywood     670.0   Millions      USD  English    3    420.0

# %%
df
# Out:
#            release_year  imdb_rating                     studio    budget  \
# industry
# Bollywood          1955          8.3  Government of West Bengal  70000.00
# Hollywood          2022          7.0             Marvel Studios    200.00
# Hollywood          2013          6.8             Marvel Studios    165.00
# Hollywood          2017          7.9             Marvel Studios    180.00
# Hollywood          2022          6.8             Marvel Studios    250.00
# Hollywood          1994          9.3  Castle Rock Entertainment     25.00
# Hollywood          2014          8.6      Warner Bros. Pictures    165.00
# Hollywood          2006          8.0          Columbia Pictures     55.00
# Hollywood          2000          8.5       Universal Pictures      103.00
# Hollywood          1997          7.9         Paramount Pictures    200.00
# Hollywood          1946          8.6              Liberty Films      3.18
# ...

# %%
df.index
# Out:
# Index(['Bollywood', 'Hollywood', 'Hollywood', 'Hollywood', 'Hollywood',
#        'Hollywood', 'Hollywood', 'Hollywood', 'Hollywood', 'Hollywood',
#        'Hollywood', 'Hollywood', 'Hollywood', 'Hollywood', 'Hollywood',
#        'Hollywood', 'Hollywood', 'Hollywood', 'Hollywood', 'Hollywood',
#        'Hollywood', 'Bollywood', 'Bollywood', 'Bollywood', 'Bollywood',
#        'Bollywood', 'Bollywood', 'Bollywood', 'Bollywood', 'Bollywood',
#        'Bollywood', 'Bollywood', 'Bollywood', 'Bollywood', 'Bollywood',
#        'Bollywood', 'Bollywood'],
#       dtype='object', name='industry')

# %%
df.loc["Bollywood"]
# Out:
#            release_year  imdb_rating                     studio   budget  \
# industry
# Bollywood          1955          8.3  Government of West Bengal  70000.0
# Bollywood          1995          8.0             Yash Raj Films    400.0
# Bollywood          2009          8.4         Vinod Chopra Films    550.0
# Bollywood          2001          7.4         Dharma Productions    390.0
# Bollywood          2015          7.2                        NaN      1.4
# Bollywood          2007          8.3                        NaN    120.0
# Bollywood          2003          8.1   Vinod Chopra Productions    100.0
# Bollywood          2014          8.1         Vinod Chopra Films    850.0
# Bollywood          2018          NaN         Vinod Chopra Films      1.0
# Bollywood          2022          8.3                Zee Studios    250.0
# Bollywood          2015          8.1          Salman Khan Films    900.0
# Bollywood          2018          1.9          Salman Khan Films      1.8
# ...

# %%
df.reset_index()
# Out:
#      industry  release_year  imdb_rating                     studio    budget  \
# 0   Bollywood          1955          8.3  Government of West Bengal  70000.00
# 1   Hollywood          2022          7.0             Marvel Studios    200.00
# 2   Hollywood          2013          6.8             Marvel Studios    165.00
# 3   Hollywood          2017          7.9             Marvel Studios    180.00
# 4   Hollywood          2022          6.8             Marvel Studios    250.00
# 5   Hollywood          1994          9.3  Castle Rock Entertainment     25.00
# 6   Hollywood          2014          8.6      Warner Bros. Pictures    165.00
# 7   Hollywood          2006          8.0          Columbia Pictures     55.00
# 8   Hollywood          2000          8.5       Universal Pictures      103.00
# 9   Hollywood          1997          7.9         Paramount Pictures    200.00
# 10  Hollywood          1946          8.6              Liberty Films      3.18
# ...

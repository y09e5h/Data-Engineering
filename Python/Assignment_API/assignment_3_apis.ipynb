# %% [markdown]
# <h2 align="center" style="color:blue">Codebasics Python Course: Exercise - APIs in Python</h2>

# %% [markdown]
# The Open Brewery DB API offers detailed data on various breweries across the United States.
#
# --
#
# ### Task 1: Fetch Brewery Data for Non-alcoholic Drink manufacturer - US client
#
# **Scenario:**
#
# As Tony Sharma mentioned during the call, he needs details about all the breweries in a specific state.
#
# Your task is to use the Open Brewery DB API to fetch and display brewery details based on a given state, which will be helpful for his client call tomorrow.
#
# **Write a Python program that:**
#
# 1. Uses the `requests` library to call the Open Brewery DB API to fetch brewery data based on a given state.
# 2. Parses the JSON response.
# 3. Extracts and displays the name, type, and location (city) of each brewery.
# 4. Handles errors gracefully (e.g., network issues or invalid API requests).
#
# Example URL for Texas Breweries: `https://api.openbrewerydb.org/breweries?by_state=texas`

# %%
# write your code here
import requests
req_params = {
    "by_state":"new york"
}
url = "https://api.openbrewerydb.org/v1/breweries"
try :

    response = requests.get(url, params=req_params)

    if response.status_code == 200:
        data = response.json()
        new_data = [ {"name" : d["name"] , "type" : d["brewery_type"],"location" : d["city"]} for d in data]
        print(new_data)
    elif response.status_code == 400:
        print("Bad Request ", response.status_code)
    elif response.status_code == 404:
        print("Not Found")
    else:
        print("Error")
except requests.exceptions.HTTPError as errh:
    print("Http Error:", errh)
except Exception as e:
    print("Error: ", e)
# Out:
# [{'name': '12 Gates Brewing Company', 'type': 'brewpub', 'location': 'Williamsville'}, {'name': '16 Stone Brewpub', 'type': 'brewpub', 'location': 'Holland Patent'}, {'name': "1940's Brewing Company", 'type': 'micro', 'location': 'Holbrook'}, {'name': '2 Way Brewing Company', 'type': 'brewpub', 'location': 'Beacon'}, {'name': '212 Brewing Company', 'type': 'contract', 'location': 'Davenport'}, {'name': '42 North Brewing Company', 'type': 'brewpub', 'location': 'East Aurora'}, {'name': '6 Degrees of Separation', 'type': 'brewpub', 'location': 'Ossining'}, {'name': '7 Sins Brewery', 'type': 'micro', 'location': 'Ripley'}, {'name': '8th Ward Brewing Company', 'type': 'planning', 'location': 'Poughkeepsie'}, {'name': 'Abandon Brewing', 'type': 'micro', 'location': 'Penn Yan'}, {'name': 'Adirondack Pub and Brewery', 'type': 'micro', 'location': 'Lake George'}, {'name': 'Adirondack Toboggan Company Microbrewery', 'type': 'micro', 'location': 'Gouverneur'}, {'name': 'Akwesasne Mohawk Casino Resort', 'type': 'planning', 'location': 'Akwesasne'}, {'name': 'Alewife Brewing Company', 'type': 'brewpub', 'location': 'Long Island City'}, {'name': 'Alphabet City Brewing Co', 'type': 'contract', 'location': 'New York'}, {'name': 'Amber Lantern Brewing Company', 'type': 'brewpub', 'location': 'Warsaw'}, {'name': 'Andean Brewing', 'type': 'micro', 'location': 'Blauvelt'}, {'name': 'Anheuser-Busch Inc â\x80\x93 Baldwinsville', 'type': 'large', 'location': 'Baldwinsville'}, {'name': 'Apex Brewery', 'type': 'micro', 'location': 'Monroe'}, {'name': 'Argyle Brewing Company', 'type': 'micro', 'location': 'Greenwich'}, {'name': 'Arrowood Farms', 'type': 'micro', 'location': 'Accord'}, {'name': 'Artisanal Brew Works', 'type': 'micro', 'location': 'Saratoga Springs'}, {'name': 'Aurora Ale & Lager', 'type': 'micro', 'location': 'King Ferry'}, {'name': 'Ausable Brewing Co', 'type': 'micro', 'location': 'Keeseville'}, {'name': 'B9 Beverages Inc', 'type': 'contract', 'location': 'New York'}, {'name': 'Bacchus Brewing', 'type': 'micro', 'location': 'Dryden'}, {'name': 'Bandwagon Brewery', 'type': 'micro', 'location': 'Interlaken'}, {'name': 'BarkEater Craft Brewery', 'type': 'proprietor', 'location': 'Lowville'}, {'name': 'Barnshed Brewing', 'type': 'micro', 'location': 'Hicksville'}, {'name': 'Barrage Brewing Co', 'type': 'micro', 'location': 'Farmingdale'}, {'name': 'Barrier Brewing Co', 'type': 'micro', 'location': 'Oceanside'}, {'name': 'Battle Hill Brewing Company', 'type': 'micro', 'location': 'Fort Ann'}, {'name': 'Beer Tree Brew Co', 'type': 'micro', 'location': 'Port Crane'}, {'name': 'Bellport Brewing Company', 'type': 'proprietor', 'location': 'Rocky Point'}, {'name': 'Big Alice Brewing Company', 'type': 'micro', 'location': 'Long Island City'}, {'name': 'Big Ditch Brewing Company', 'type': 'micro', 'location': 'Buffalo'}, {'name': 'Big Inlet Brewing', 'type': 'planning', 'location': 'Mayville'}, {'name': 'Big Slide Brewery', 'type': 'brewpub', 'location': 'Lake Placid'}, {'name': 'Big Tupper Brewing', 'type': 'brewpub', 'location': 'Tupper Lake'}, {'name': 'Binghamton Brewing Co', 'type': 'micro', 'location': 'Johnson City'}, {'name': 'Birreria @ Eataly', 'type': 'brewpub', 'location': 'New York'}, {'name': 'Black Forest Brew Haus', 'type': 'brewpub', 'location': 'Farmingdale'}, {'name': 'Blind Bat Brewery LLC, The', 'type': 'micro', 'location': 'Centerport'}, {'name': 'Blue Collar Brewery, Inc.', 'type': 'brewpub', 'location': 'Poughkeepsie'}, {'name': 'Blue Line Brewery', 'type': 'brewpub', 'location': 'Saranac Lake'}, {'name': 'Blue Point Brewing', 'type': 'large', 'location': 'Patchogue'}, {'name': 'Blue Point Brewing Co', 'type': 'large', 'location': 'Patchogue'}, {'name': 'Bolton Landing Brewing Co.', 'type': 'micro', 'location': 'Bolton Landing'}, {'name': 'Boots Brewing Company, Inc.', 'type': 'micro', 'location': 'Watertown'}, {'name': 'Bottomless Brewing, LLC', 'type': 'brewpub', 'location': 'Geneva'}]

# %% [markdown]
# JSONPlaceholder offers a set of APIs for typical CRUD (Create, Read, Update, Delete) operations, making it an excellent resource for learning and testing HTTP requests.
#
# --
#
# ### Task 2: Fetch User Data for AtliQ Client Project
#
# **Scenario:** As a quick favor, Loki shared an ad-hoc task with you. He needs help with a user profile component for an Atliq client application, using JSONPlaceholder to simulate fetching user data.
#
# **Objective:** Create a function `fetch_user_data` that uses JSONPlaceholder’s API to retrieve and format user details.
#
# **Steps:**
#
# 1. Fetch user data from JSONPlaceholder.
# 2. Format the data to include 'name', 'email', and 'address'.
# 3. Return the data as a dictionary.
#
# **Expected Output:**
#
# ```
# {
#     'name': 'Leanne Graham',
#     'email': 'Sincere@april.biz',
#     'address': 'Kulas Light, Gwenborough'
# }
#
#
#
# ```

# %%
# write your code here

url = 'https://jsonplaceholder.typicode.com/posts'

req_params = {"userId":1}
response = requests.get(url, params=req_params)
try :
    if response.status_code == 200:
        new_data = [{"title": data["title"]} for data in response.json()]
        print(new_data)
except requests.exceptions.HTTPError as errh:
    print("Http Error:", errh)
except Exception as e:
    print("Error: ", e)
# Out:
# [{'title': 'sunt aut facere repellat provident occaecati excepturi optio reprehenderit'}, {'title': 'qui est esse'}, {'title': 'ea molestias quasi exercitationem repellat qui ipsa sit aut'}, {'title': 'eum et est occaecati'}, {'title': 'nesciunt quas odio'}, {'title': 'dolorem eum magni eos aperiam quia'}, {'title': 'magnam facilis autem'}, {'title': 'dolorem dolore est ipsam'}, {'title': 'nesciunt iure omnis dolorem tempora et accusantium'}, {'title': 'optio molestias id quia eum'}]

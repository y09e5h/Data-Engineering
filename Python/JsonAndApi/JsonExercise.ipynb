# %%
json_string='''
{
  "firstName": "Jane",
  "lastName": "Smith",
  "address": {
    "street": "123 Maple Avenue",
    "city": "Springfield",
    "state": "IL",
    "zip": "62704"
  },
  "tags": ["engineer", "remote", "verified"]
}
'''

# %%
import json as json

# %%
data = json.loads(json_string)

# %%
data
# Out:
# {'firstName': 'Jane',
#  'lastName': 'Smith',
#  'address': {'street': '123 Maple Avenue',
#   'city': 'Springfield',
#   'state': 'IL',
#   'zip': '62704'},
#  'tags': ['engineer', 'remote', 'verified']}

# %%
data["address"]["street"]
# Out:
# '123 Maple Avenue'

# %%
data["tags"][0]
# Out:
# 'engineer'

# %%
data["tags"][1]
# Out:
# 'remote'

# %%
with open("output.json", "w") as outfile:
    json.dump(data, outfile, indent=4)

# %%
with open("products.json", "r") as infile:
    products = json.load(infile)

products
# Out:
# [{'product_id': 1,
#   'sku': 'ABC123',
#   'name': 'Wireless Mouse',
#   'price': 25.99,
#   'description': 'A comfortable wireless mouse with ergonomic design.',
#   'in_stock': True,
#   'category': 'Electronics'},
#  {'product_id': 2,
#   'sku': 'XYZ789',
#   'name': 'Mechanical Keyboard',
#   'price': 89.99,
#   'description': 'A high-quality mechanical keyboard with customizable keys.',
#   'in_stock': True,
#   'category': 'Electronics'},
#  {'product_id': 3,
#   'sku': 'LMN456',
#   'name': 'USB-C Charger',
#   'price': 19.99,
#   'description': 'A fast-charging USB-C charger with multiple ports.',
#   'in_stock': False,
#   'category': 'Accessories'},
#  {'product_id': 4,
#   'sku': 'QWE234',
#   'name': 'Bluetooth Speaker',
#   'price': 49.99,
#   'description': 'A portable Bluetooth speaker with excellent sound quality.',
#   'in_stock': True,
#   'category': 'Audio'},
#  {'product_id': 5,
#   'sku': 'RTY678',
#   'name': 'Smartphone Stand',
#   'price': 14.99,
#   'description': 'An adjustable smartphone stand for hands-free viewing.',
#   'in_stock': True,
#   'category': 'Accessories'}]

# %%
new_data = [{"Name" : product["name"], "Price" : product["price"]} for product in products]

new_data
# Out:
# [{'Name': 'Wireless Mouse', 'Price': 25.99},
#  {'Name': 'Mechanical Keyboard', 'Price': 89.99},
#  {'Name': 'USB-C Charger', 'Price': 19.99},
#  {'Name': 'Bluetooth Speaker', 'Price': 49.99},
#  {'Name': 'Smartphone Stand', 'Price': 14.99}]

# %%
type(new_data)
# Out:
# list

# %%
json_string = '''{
  "type": "Feature",
  "geometry": {
    "type": "Point"
    "coordinates": [-73.935242, 40.73061]
  },
  "properties": {
    "name": "New York City"
  }
}'''

json.loads(json_string)
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# Cell In[26], line 12
#       1 json_string = '''{
#       2   "type": "Feature",
#       3   "geometry": {
#    (...)      9   }
#      10 }'''
# ---> 12 json.loads(json_string)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\json\__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     341     s = s.decode(detect_encoding(s), 'surrogatepass')
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#     348     cls = JSONDecoder
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\json\decoder.py:345, in JSONDecoder.decode(self, s, _w)
#     340 def decode(self, s, _w=WHITESPACE.match):
#     341     """Return the Python representation of ``s`` (a ``str`` instance
#     342     containing a JSON document).
#     343
#     344     """
# --> 345     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     346     end = _w(s, end).end()
#     347     if end != len(s):
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\json\decoder.py:361, in JSONDecoder.raw_decode(self, s, idx)
#     352 """Decode a JSON document from ``s`` (a ``str`` beginning with
#     353 a JSON document) and return a 2-tuple of the Python
#     354 representation and the index in ``s`` where the document ended.
#    (...)    358
#     359 """
#     360 try:
# --> 361     obj, end = self.scan_once(s, idx)
#     362 except StopIteration as err:
#     363     raise JSONDecodeError("Expecting value", s, err.value) from None
#
# JSONDecodeError: Expecting ',' delimiter: line 5 column 5 (char 63)

# %%
try :
    data = json.loads(json_string)
except json.JSONDecodeError as e:
    print(f"Error parsing json data : {e}")
# Out:
# Error parsing json data : Expecting ',' delimiter: line 5 column 5 (char 63)

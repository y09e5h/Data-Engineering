# %%
print("hello")
# Out:
# hello

# %%
1+1
# Out:
# 2

# %%
s="this is 10"
print(s)
# Out:
# this is 10

# %%
id(s)
# Out:
# 2282206363888

# %%
id(s)
# Out:
# 2282206363888

# %%
s=s.replace("10","11")

# %%
id(s)
# Out:
# 2282206376752

# %%
a=10

# %%
id(a)
# Out:
# 140725309240520

# %%
a=20

# %%
id(a)
# Out:
# 140725309240840
